# %%
import numpy as np
# %reload_ext tikzmagic
# %matplotlib inline
from IPython.display import HTML

# %% [markdown]
# # An introduction to the iPython Notebook
#
# This notebook / presentation will give a quick introduction to the iPython Notebook.
#
# 1. Why use a notebook?
# 2. How to use a notebook?
#  - prerequisites and installation
#  - markdown
#  - modules
#  - export
# 3. Some demos
#  - signal analysis
#  - image analysis
#  - publication

# %% [markdown]
# ## Why use a notebook?

# %%
# %%tikz --size 600,800
# \tikzstyle{line} = [draw, -latex'];
# \tikzstyle{block} = [rectangle, draw, fill=blue!20, text width=10em, text centered, rounded corners, minimum height=4em];
# \tikzstyle{block2} = [rectangle, draw, fill=red!20, text width=10em, text centered, rounded corners, minimum height=2em];
#
#                     \draw[thick,rounded corners] (-8,-14) rectangle (8,2);
#
# \node at (0,0) [block] (lit) {Literature Review};
# \node at (0,-2) [block] (exp0) {Experimental Design};
# \node at (0,-4) [block] (exp1) {Data Acquisition};
# \node at (0,-6) [block] (proc) {Data Processing};
# \node at (0,-8) [block] (figs) {Data Visualization};
# \node at (0,-10) [block] (comm) {Data communication};
# \node at (0,-12) [block] (pub) {Data publishing};
# \draw [->] (lit)--(exp0);
# \draw [->] (exp0)--(exp1);
# \draw [->] (exp1)--(proc);
# \draw [->] (proc)--(figs);
# \draw [->] (figs)--(comm);
# \draw [->] (comm)--(pub);
# \draw [->,rounded corners] (comm) -- (4,-10) -- (4,-6) -- (proc);

# %%
# %%tikz --size 600,800
# \tikzstyle{line} = [draw, -latex'];
# \tikzstyle{block} = [rectangle, draw, fill=blue!20, text width=10em, text centered, rounded corners, minimum height=4em];
# \tikzstyle{block2} = [rectangle, draw, fill=red!20, text width=10em, text centered, rounded corners, minimum height=2em];
#
#                     \draw[thick,rounded corners] (-8,-14) rectangle (8,2);
#
# \node at (0,0) [block] (lit) {Literature Review};
# \node at (0,-2) [block] (exp0) {Experimental Design};
# \node at (0,-4) [block] (exp1) {Data Acquisition};
# \node at (0,-6) [block] (proc) {Data Processing};
# \node at (0,-8) [block] (figs) {Data Visualization};
# \node at (0,-10) [block] (comm) {Data communication};
# \node at (0,-12) [block] (pub) {Data publishing};
# \draw [->] (lit)--(exp0);
# \draw [->] (exp0)--(exp1);
# \draw [->] (exp1)--(proc);
# \draw [->] (proc)--(figs);
# \draw [->] (figs)--(comm);
# \draw [->] (comm)--(pub);
# \draw [->,rounded corners] (comm) -- (4,-10) -- (4,-6) -- (proc);
#
# \node at (-4,0) [block2] (lit) {Latex / Word};
# \node at (-4,-2) [block2] (exp0) {Excel / Drive};
# \node at (-4,-4) [block2] (exp1) {LabView / CFD};
# \node at (-4,-6) [block2] (proc) {MATLAB / Python / C};
# \node at (-4,-8) [block2] (figs) {MATLAB / Tecplot / gnuplot};
# \node at (-4,-10) [block2] (comm) {Latex / Word};
# \node at (-4,-12) [block2] (pub) {Latex};

# %%
# %%tikz --size 600,800
# \tikzstyle{line} = [draw, -latex'];
# \tikzstyle{block} = [rectangle, draw, fill=blue!20, text width=10em, text centered, rounded corners, minimum height=4em];
# \tikzstyle{block2} = [rectangle, draw, fill=red!20, text width=10em, text centered, rounded corners, minimum height=2em];
# \tikzstyle{block3} = [rectangle, draw, fill=green!20, text width=10em, text centered, rounded corners, minimum height=2em];
# \tikzstyle{block4} = [rectangle, draw, fill=red!60, text width=10em, text centered, rounded corners, minimum height=2em];
#
#                     \draw[thick,rounded corners] (-8,-14) rectangle (8,2);
#
# \node at (0,0) [block] (lit) {Literature Review};
# \node at (0,-2) [block] (exp0) {Experimental Design};
# \node at (0,-4) [block] (exp1) {Data Acquisition};
# \node at (0,-6) [block] (proc) {Data Processing};
# \node at (0,-8) [block] (figs) {Data Visualization};
# \node at (0,-10) [block] (comm) {Data communication};
# \node at (0,-12) [block] (pub) {Data publishing};
# \draw [->] (lit)--(exp0);
# \draw [->] (exp0)--(exp1);
# \draw [->] (exp1)--(proc);
# \draw [->] (proc)--(figs);
# \draw [->] (figs)--(comm);
# \draw [->] (comm)--(pub);
# \draw [->,rounded corners] (comm) -- (4,-10) -- (4,-6) -- (proc);
#
# \node at (-4,0) [block2] (lit) {Latex / Word};
# \node at (-4,-2) [block2] (exp0) {Excel / Drive / Notepad};
# \node at (-4,-4) [block2] (exp1) {LabView / CFD};
# \node at (-4,-6) [block2] (proc) {MATLAB / Python / C};
# \node at (-4,-8) [block2] (figs) {MATLAB / Tecplot / gnuplot};
# \node at (-4,-10) [block2] (comm) {Latex / Word};
# \node at (-4,-12) [block2] (pub) {Latex};
#
# \node at (4,0) [block3] (lit) {Works with Bibtex};
# \node at (4,-2) [block4] (exp0) {Notepad still the best};
# \node at (4,-4) [block4] (exp1) {LabView / CFD};
# \node at (4,-6) [block3] (proc) {SciPy};
# \node at (4,-8) [block3] (figs) {Matplotlib};
# \node at (4,-10) [block3] (comm) {Markdown};
# \node at (4,-12) [block3] (pub) {Output to tex};

# %%
# %%tikz --size 600,800
# \tikzstyle{line} = [draw, -latex'];
# \tikzstyle{block} = [rectangle, draw, fill=blue!20, text width=10em, text centered, rounded corners, minimum height=4em];
# \tikzstyle{block2} = [rectangle, draw, fill=red!20, text width=10em, text centered, rounded corners, minimum height=2em];
# \tikzstyle{block3} = [rectangle, draw, fill=green!20, text width=10em, text centered, rounded corners, minimum height=2em];
# \tikzstyle{block4} = [rectangle, draw, fill=red!60, text width=10em, text centered, rounded corners, minimum height=2em];
# \tikzstyle{block5} = [rectangle, draw, fill=blue!60, text width=10em, text centered, rounded corners, minimum height=2em];
#
#                     \draw[thick,rounded corners] (-8,-14) rectangle (8,2);
#
# \node at (0,0) [block] (lit) {Literature Review};
# \node at (0,-2) [block] (exp0) {Experimental Design};
# \node at (0,-4) [block] (exp1) {Data Acquisition};
# \node at (0,-6) [block] (proc) {Data Processing};
# \node at (0,-8) [block] (figs) {Data Visualization};
# \node at (0,-10) [block] (comm) {Data communication};
# \node at (0,-12) [block] (pub) {Data publishing};
# \draw [->] (lit)--(exp0);
# \draw [->] (exp0)--(exp1);
# \draw [->] (exp1)--(proc);
# \draw [->] (proc)--(figs);
# \draw [->] (figs)--(comm);
# \draw [->] (comm)--(pub);
# \draw [->,rounded corners] (comm) -- (4,-10) -- (4,-6) -- (proc);
#
# \node at (-4,0) [block2] (lit) {Latex / Word};
# \node at (-4,-2) [block2] (exp0) {Excel / Drive / Notepad};
# \node at (-4,-4) [block2] (exp1) {LabView / CFD};
# \node at (-4,-6) [block2] (proc) {MATLAB / Python / C};
# \node at (-4,-8) [block2] (figs) {MATLAB / Tecplot / gnuplot};
# \node at (-4,-10) [block2] (comm) {Latex / Word};
# \node at (-4,-12) [block2] (pub) {Latex};
#
# \node at (4,0) [block3] (lit) {Works with Bibtex};
# \node at (4,-2) [block4] (exp0) {Notepad still the best};
# \node at (4,-4) [block4] (exp1) {LabView / CFD};
# \node at (4,-6) [block5] (proc) {SciPy};
# \node at (4,-8) [block5] (figs) {Matplotlib};
# \node at (4,-10) [block5] (comm) {Markdown};
# \node at (4,-12) [block3] (pub) {Output to tex};

# %% [markdown]
# ## How to use a notebook?
#
# ### Installation:
#
# #### On linux:
#
# 1. Download python 2.7.10
# 2. Download python 3.4.3
#
#     pip install ipython
#
# #### On windows / mac:
# 1. Download anaconda
#
#         conda update conda
#         conda update ipython ipython-notebook ipython-qtconsole

# %% [markdown]
# ### Running:
#
# #### To run locally:
#     ipython notebook
# #### To run server:
# 1. Create a SSL certificate
#         openssl req -x509 -nodes -days 365 -newkey rsa:1024 -keyout mycert.pem -out mycert.pem
# 2. Secure notebook server with a password:
#         ipython
#         from IPython.lib import passwd
#         passwd()
# 3. Create a server profile
#         ipython profile create nbserver
# 4. Edit that profile as follows, edit ```ipython_notebook_config.py```
#         c.NotebookApp.certfile = u'path to mycert.pem'
#         c.NotebookApp.ip = '*'
#         c.NotebookApp.open_browser = False
#         c.NotebookApp.password = u'[your hashed password here]'
#         c.NotebookApp.port = 9999
# 5. Launch notebook with
#         ipython notebook --profile=nbserver
# 6. Must browse to [https://IP:PORT](https://130.194.130.230:8008/)

# %% [markdown]
# ### A notebook is a mix of text, code, and graphics
# [A demo](http://mec-obiwan.eng.monash.edu.au/~james/Summary.html)

# %% [markdown]
# ### Markdown formating
#     ### Markdown formating
#
# An introduction to the syntax is [here](http://daringfireball.net/projects/markdown/syntax).
#
#     An introduction to the syntax is [here](http://daringfireball.net/projects/markdown/syntax).
#
# #### Codes - indent 4 spaces or 1 tab
#     This is code.
#         With indents
#     And back to normal
#
# Or, we can do inline code like `this is some more code`.
#
# #### Emphasis
#
# - *Italics* or **double asterisks**
#
#     ```*Italics* or **double asterisks**```
#
#
# #### Latex - out of the box
# $$c = \sqrt{a^2 + b^2}$$
# $$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$
#
#     $$c = \sqrt{a^2 + b^2}$$
#     $$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$

# %% [markdown]
# ### Modules and user-functions
#
# - NumPy - Numerical Python, array handling, math functions
# - SciPy - Scientific Python, optimization, signal processing, linear algebra, etc.
# - PIL - Python Image Library, image manipulation
# - MatPlotLib - MATLAB Plotting Library - MATLAB style plots
# - tikz - load_ext tikzmagic
# - ModRed - Model Reduction - Claren Rowley's group at Princeton
# - wclablib - provides PSD type functions
#         sudo python3.4 setup.py install
# - pivio / imgio - interface for dealing with PIV binaries

# %% [markdown]
# ### Some coding things
#  - ipython notebook runs in browser window
#  - memory exists in the kernel only
#  - tab autocomplete
#  - append ? to give information about a variable
#  - indexing starts at zero
#  - smart indexing
#  - run with control-enter
#  - loops
#  - comment block with control-/

# %% [markdown]
# ### Export ipython
#
#     ipython nbconvert --to FORMAT file.ipynb
#
#  - to pdf
#  - to latex
#  - to slides
#  - to [html](http://mec-obiwan.eng.monash.edu.au/~james/Summary.html)

# %% [markdown]
# ### Demo #1
# [Run on James' server](https://130.194.130.230:8008/)

# %%
x = 12
y = 4
z = x^2 +y

print(z)

z = x**2 + 2*y

print(z)
# Out:
# 10
# 152

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()">The raw code for this IPython notebook is by default hidden for easier reading.To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()">The raw code for this IPython notebook is by default hidden for easier reading.To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a></form>
